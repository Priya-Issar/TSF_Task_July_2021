# %% [markdown]
# <a href="https://colab.research.google.com/github/Priya-Issar/TSF_Task_July_2021/blob/main/Task_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Name - Priya Issar
#
# ## Batch - GRIP July 2021
#
# ## CV & IOT Internship at TSF
#
# ## Task 4-Detection of Face Mask
#
# ## Task Code Explanation Notebook -PriyaIssar_Taskcode_Explanation.ipynb
# https://colab.research.google.com/drive/1RSpm5IpCuKJaMrj8qgeiFMAgYFpgcam2?usp=sharing
#
# I have used YOLOv3 object detection algorithm in this task.

# %%
#mount the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#checking the directories in folder
# !ls '/content/drive/MyDrive/yolov3'
# Out:
# backup	   chart_yolov3_custom.png  custom_weight  images.zip
# chart.png  custom_data		    darknet

# %%
#First Upload the images in the google drive folder
#unzip the images present in images folder 
#the output folder which contains images id custom_data
# !unzip '/content/drive/MyDrive/yolov3/images.zip' -d '/content/drive/MyDrive/yolov3'
# Out:
# Archive:  /content/drive/MyDrive/yolov3/images.zip
#   inflating: /content/drive/MyDrive/yolov3/Z_DataSet_MaskDetection/1.jpeg
#   inflating: /content/drive/MyDrive/yolov3/Z_DataSet_MaskDetection/1.txt
#   inflating: /content/drive/MyDrive/yolov3/Z_DataSet_MaskDetection/10.jpeg
#   inflating: /content/drive/MyDrive/yolov3/Z_DataSet_MaskDetection/10.txt
#   inflating: /content/drive/MyDrive/yolov3/Z_DataSet_MaskDetection/11.jpeg
#   inflating: /content/drive/MyDrive/yolov3/Z_DataSet_MaskDetection/11.txt
#   inflating: /content/drive/MyDrive/yolov3/Z_DataSet_MaskDetection/12.jpeg
#   inflating: /content/drive/MyDrive/yolov3/Z_DataSet_MaskDetection/12.txt
#   inflating: /content/drive/MyDrive/yolov3/Z_DataSet_MaskDetection/13.jpg
#   inflating: /content/drive/MyDrive/yolov3/Z_DataSet_MaskDetection/13.txt
#   inflating: /content/drive/MyDrive/yolov3/Z_DataSet_MaskDetection/15.jpg
#   inflating: /content/drive/MyDrive/yolov3/Z_DataSet_MaskDetection/15.txt
# ...

# %%
#clone the darknet Github repository
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/MyDrive/yolov3/darknet'
# Out:
# Cloning into '/content/drive/MyDrive/yolov3/darknet'...
# remote: Enumerating objects: 14997, done.
# remote: Total 14997 (delta 0), reused 0 (delta 0), pack-reused 14997
# Receiving objects: 100% (14997/14997), 13.38 MiB | 7.79 MiB/s, done.
# Resolving deltas: 100% (10194/10194), done.
# Checking out files: 100% (2024/2024), done.

# %%
# %cd /content/drive/MyDrive/yolov3/darknet #command used to change directory
# Out:
# /content/drive/MyDrive/yolov3/darknet

# %%
ls #this will give files present in darknet folder
# Out:
# 3rdparty/       DarknetConfig.cmake.in  json_mjpeg_streams.sh  scripts/
# backup/         darknet_images.py       LICENSE                src/
# build/          darknet.py              Makefile               vcpkg.json
# build.ps1       darknet_video.py        net_cam_v3.sh          video_yolov3.sh
# cfg/            data/                   net_cam_v4.sh          video_yolov4.sh
# cmake/          image_yolov3.sh         obj/
# CMakeLists.txt  image_yolov4.sh         README.md
# darknet         include/                results/

# %%
#change the GPU , CUDNN , OPENCV value to 1 , since these are used during training
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile

# %%
# !make # to compile the model ,makefile is needed
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# %cd  /content/drive/MyDrive/yolov3
# Out:
# /content/drive/MyDrive/yolov3

# %%
# !python custom_data/creating-files-data-and-name.py

# %%
#this will make train.txt and test.txt files for training the model
# !python custom_data/creating-train-and-test-txt-files.py

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>

# %% [markdown]
#  darknet53.conv.74 is intial yolo weights for training custom data

# %%
#Training starts
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 61539, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.907505), count: 3, class_loss = 0.001556, iou_loss = 0.155915, total_loss = 0.157471
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# ...
